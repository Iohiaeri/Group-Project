# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
colnames=['day', 'time', 'tide']
df = pd.read_fwf(r'ASTR19_S22_group_project_data.txt', header=None, skiprows=(0,1,2), names=colnames)
x = np.linspace(1, 82, 82)
y = df['tide']
y_err = np.full(82,.25)
yfit = 2.5*-np.cos(np.pi*x)+2.48

# %%
plt.errorbar(x,y,y_err,fmt='o')
plt.plot(x, yfit)
plt.show()

# %%
ydata = df['tide'].tolist()
yfitdata = yfit.tolist()

# %%
residual = []
for i in range(82):
    residual.append(ydata[i]-yfit[i])

# %%
plt.hist(residual, bins=45)
# Out:
# (array([1., 0., 1., 0., 1., 2., 0., 0., 0., 1., 5., 2., 4., 3., 3., 4., 4.,
#         4., 2., 2., 4., 1., 1., 5., 5., 0., 1., 4., 1., 2., 1., 0., 0., 3.,
#         3., 3., 0., 2., 1., 2., 1., 0., 1., 1., 1.]),
#  array([-3.15      , -3.00711111, -2.86422222, -2.72133333, -2.57844444,
#         -2.43555556, -2.29266667, -2.14977778, -2.00688889, -1.864     ,
#         -1.72111111, -1.57822222, -1.43533333, -1.29244444, -1.14955556,
#         -1.00666667, -0.86377778, -0.72088889, -0.578     , -0.43511111,
#         -0.29222222, -0.14933333, -0.00644444,  0.13644444,  0.27933333,
#          0.42222222,  0.56511111,  0.708     ,  0.85088889,  0.99377778,
#          1.13666667,  1.27955556,  1.42244444,  1.56533333,  1.70822222,
#          1.85111111,  1.994     ,  2.13688889,  2.27977778,  2.42266667,
#          2.56555556,  2.70844444,  2.85133333,  2.99422222,  3.13711111,
#          3.28      ]),
#  <BarContainer object of 45 artists>)
